# %%
import json
from pathlib import Path
import pandas as pd

# %%
Path.cwd()
# Out:
# PosixPath('/project/6047694/tvhahn/arxiv-code-search/notebooks')

# %%
project_dir = Path.cwd().parent

raw_data_dir = project_dir / 'data/raw'
print(raw_data_dir)
# Out:
# /project/6047694/tvhahn/arxiv-code-search/data/raw

# %%
arxiv_json_path = raw_data_dir / "arxiv-metadata-oai-snapshot.json"

# %%
metadata  = []
with open(arxiv_json_path, 'r') as f:
    for line in f: 
        metadata.append(json.loads(line))

# %%
# for testing 
df = pd.DataFrame(metadata)
print(df.shape)
# Out:
# (2036497, 14)

# %%
df.tail()
# Out:
#                        id           submitter  \
# 2036492  supr-con/9608008     Ruslan Prozorov
# 2036493  supr-con/9609001  Durga P. Choudhury
# 2036494  supr-con/9609002  Durga P. Choudhury
# 2036495  supr-con/9609003   Hasegawa Yasumasa
# 2036496  supr-con/9609004    Masanori Ichioka
#
#                                                    authors  \
# 2036492  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2036493  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2036494  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2036495  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2036496  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 2036492  On the origin of the irreversibility line in t...
# 2036493  Nonlinear Response of HTSC Thin Film Microwave...
# 2036494  Critical State Flux Penetration and Linear Mic...
# 2036495  Density of States and NMR Relaxation Rate in A...
# ...

# %%
# df['update_date'] = pd.to_datetime(df['update_date'])

# %%
df.sort_values('update_date', ascending=False).head()
# Out:
#                  id        submitter  \
# 1622013  2203.09151      Xiaotong Ji
# 1621933  2203.09071     Minghao Wang
# 1621903  2203.09041       Qing Chang
# 1579471  2112.09695  Eshagh Farzaneh
# 1621902  2203.09040         Fuxun Yu
#
#                                                    authors  \
# 1622013  Xiaotong Ji, Yuchen Zheng, Daiki Suehiro, Seii...
# 1621933                      Minghao Wang and Gongwang Yan
# 1621903  Qing Chang, Junran Peng, Lingxie Xie, Jiajun S...
# 1579471             Eshagh Farzaneh Joubaneh and Jihong Ma
# 1621902  Fuxun Yu, Di Wang, Longfei Shangguan, Minjia Z...
#
#                                                      title  \
# 1622013  Optimal Rejection Function Meets Character Rec...
# 1621933  Homotopy transfer for QFT on non-compact manif...
# 1621903     DATA: Domain-Aware and Task-Aware Pre-training
# 1579471  Symmetry Effect on the Dynamic Behaviors of Sa...
# 1621902  A Survey of Multi-Tenant Deep Learning Inferen...
#
# ...

# %%
# random shuffle and save only portion
df = df.sample(frac=1).reset_index(drop=True)
df = df[:10000]

# %%
df.head()
# Out:
#                id            submitter  \
# 0       1410.6990          Dacheng Tao
# 1      1503.01072    Peter Schauenburg
# 2  hep-th/0410256  Diego Hernan Correa
# 3      1708.06096     Fernand Renard M
# 4      1706.06195    Ivo Gon\c{c}alves
#
#                                              authors  \
# 0      Chang Xu, Tongliang Liu, Dacheng Tao, Chao Xu
# 1                                  Peter Schauenburg
# 2  L.G. Aldrovandi, D.H. Correa, F.A. Schaposnik ...
# 3                                  Fernand M. Renard
# 4  Ivo Gon\c{c}alves, Sara Silva, Carlos M. Fonse...
#
#                                                title              comments  \
# 0  Local Rademacher Complexity for Multi-label Le...                  None
# 1  Frobenius-Schur indicators for some fusion cat...              15 pages
# 2  BPS Analysis of Gauge Field-Higgs Models in No...              11 pages
# 3               Tests of bottom quark CSM properties  20 pages, 13 figures
# ...

# %%
# save sample csv
df.to_csv('metadata_sample.csv',index=False)
